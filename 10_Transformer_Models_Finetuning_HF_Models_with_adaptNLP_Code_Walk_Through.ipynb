# %% [markdown]
# # Fastai & AdaptNLP
# Codebeispiel zur Verwendung der AdaptNLP Bibliothek. Wir betrachten ein Beispiel aus dem HuggingFace Online-Kurs und trainieren unser Modell auf Basis der `Bert`-Architektur und dem MRPC Datenset.
#
# Quellen:
#
# * https://novetta.github.io/adaptnlp
# * https://github.com/novetta/adaptnlp

# %% [markdown]
# ## Erforderliche Installationen
# Wir benötigen eine Basisbibliotheken für die Verwendung von `AdaptNLP`, wie `transformers`, `datasets` und `fastai`.

# %%
# !!pip install adaptnlp -U
#!git+https://github.com/novetta/adaptnlp@dev -U
# Out:
# ['Collecting adaptnlp',
#  '  Downloading adaptnlp-0.3.2-py3-none-any.whl (62 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█████▏                          | 10 kB 28.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▍                     | 20 kB 35.3 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▋                | 30 kB 23.3 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▉           | 40 kB 18.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 51 kB 7.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▎| 61 kB 7.7 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 62 kB 786 kB/s ',
#  '\x1b[?25hCollecting fastcore>=1.3.21',
#  '  Downloading fastcore-1.3.26-py3-none-any.whl (56 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█████▉                          | 10 kB 46.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▊                    | 20 kB 32.8 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▌              | 30 kB 40.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▍        | 40 kB 45.7 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▎  | 51 kB 34.9 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 56 kB 4.6 MB/s ',
#  '\x1b[?25hCollecting fastai>=2.4.0',
#  '  Downloading fastai-2.5.2-py3-none-any.whl (186 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█▊                              | 10 kB 47.8 MB/s eta 0:00:01',
#  '\x1b[K     |███▌                            | 20 kB 54.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████▎                          | 30 kB 63.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 40 kB 55.9 MB/s eta 0:00:01',
#  '\x1b[K     |████████▉                       | 51 kB 30.7 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▌                     | 61 kB 34.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▎                   | 71 kB 27.7 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 81 kB 29.8 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▉                | 92 kB 26.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▋              | 102 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▍            | 112 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████           | 122 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▉         | 133 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▋       | 143 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▍     | 153 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 163 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 174 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▋| 184 kB 23.0 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 186 kB 23.0 MB/s ',
#  '\x1b[?25hRequirement already satisfied: torch<2.0.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from adaptnlp) (1.9.0+cu102)',
#  'Collecting transformers<5.0.0,>=4.0.0',
#  '  Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)',
#  '\x1b[?25l',
#  '\x1b[K     |▏                               | 10 kB 45.7 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 20 kB 34.3 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 30 kB 42.2 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 40 kB 47.5 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 51 kB 51.7 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 61 kB 56.5 MB/s eta 0:00:01',
#  '\x1b[K     |▉                               | 71 kB 55.4 MB/s eta 0:00:01',
#  '\x1b[K     |█                               | 81 kB 49.9 MB/s eta 0:00:01',
#  '\x1b[K     |█▏                              | 92 kB 51.5 MB/s eta 0:00:01',
#  '\x1b[K     |█▎                              | 102 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█▍                              | 112 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█▌                              | 122 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█▋                              | 133 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█▊                              | 143 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██                              | 153 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██                              | 163 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▏                             | 174 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▎                             | 184 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▍                             | 194 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▌                             | 204 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▋                             | 215 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▉                             | 225 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███                             | 235 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███                             | 245 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▏                            | 256 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▎                            | 266 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▍                            | 276 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▌                            | 286 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▊                            | 296 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███▉                            | 307 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████                            | 317 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████                            | 327 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▏                           | 337 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▎                           | 348 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▍                           | 358 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▌                           | 368 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▊                           | 378 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████▉                           | 389 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████                           | 399 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████                           | 409 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▏                          | 419 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▎                          | 430 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▍                          | 440 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▋                          | 450 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▊                          | 460 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████▉                          | 471 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████                          | 481 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████                          | 491 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▏                         | 501 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▎                         | 512 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▌                         | 522 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▋                         | 532 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▊                         | 542 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████▉                         | 552 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 563 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 573 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▏                        | 583 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▍                        | 593 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▌                        | 604 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▋                        | 614 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▊                        | 624 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████▉                        | 634 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████                        | 645 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████                        | 655 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▏                       | 665 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▍                       | 675 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▌                       | 686 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▋                       | 696 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▊                       | 706 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████▉                       | 716 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████                       | 727 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████                       | 737 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▎                      | 747 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▍                      | 757 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▌                      | 768 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▋                      | 778 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▊                      | 788 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▉                      | 798 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████                      | 808 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▏                     | 819 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▎                     | 829 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▍                     | 839 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▌                     | 849 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▋                     | 860 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▊                     | 870 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▉                     | 880 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████                     | 890 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▏                    | 901 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▎                    | 911 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▍                    | 921 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▌                    | 931 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▋                    | 942 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▊                    | 952 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▉                    | 962 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████                    | 972 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▏                   | 983 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▎                   | 993 kB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▍                   | 1.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▌                   | 1.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▋                   | 1.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▊                   | 1.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████                   | 1.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████                   | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▏                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▎                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▍                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▌                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▋                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▉                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▏                 | 1.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▎                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▍                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▌                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▊                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▉                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████                 | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▏                | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▎                | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▍                | 1.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▌                | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▊                | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▉                | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████                | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████                | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▏               | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▎               | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▍               | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▋               | 1.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▊               | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▉               | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████               | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████               | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▏              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▎              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▌              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▋              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▊              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▉              | 1.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▏             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▍             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▌             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▋             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▊             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▉             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 1.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▏            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▍            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▌            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▋            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▊            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▉            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▎           | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▍           | 1.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▌           | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▋           | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▊           | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▉           | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████           | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▏          | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▎          | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▍          | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▌          | 1.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▋          | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▊          | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▉          | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▏         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▎         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▍         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▌         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▋         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▊         | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▉         | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████         | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▏        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▎        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▍        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▌        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▋        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▊        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████        | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▏       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▎       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▍       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▌       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▋       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▉       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▏      | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▎      | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▍      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▌      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▊      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▉      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▏     | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▎     | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▍     | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▌     | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▊     | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▉     | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████     | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████     | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▏    | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▎    | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▍    | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▋    | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▊    | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▉    | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████    | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████    | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▎   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▌   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▋   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▊   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▉   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▏  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▍  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▌  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▋  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▊  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▉  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▏ | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▍ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▌ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▋ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▊ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▉ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████ | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▎| 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▍| 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▌| 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▋| 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▊| 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▉| 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 2.6 MB 53.5 MB/s ',
#  '\x1b[?25hCollecting flair',
#  '  Downloading flair-0.9-py3-none-any.whl (319 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█                               | 10 kB 26.0 MB/s eta 0:00:01',
#  '\x1b[K     |██                              | 20 kB 29.1 MB/s eta 0:00:01',
#  '\x1b[K     |███                             | 30 kB 33.8 MB/s eta 0:00:01',
#  '\x1b[K     |████                            | 40 kB 36.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████▏                          | 51 kB 35.9 MB/s eta 0:00:01',
#  '\x1b[K     |██████▏                         | 61 kB 36.7 MB/s eta 0:00:01',
#  '\x1b[K     |███████▏                        | 71 kB 37.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████▏                       | 81 kB 39.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▎                      | 92 kB 39.4 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▎                     | 102 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▎                    | 112 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▎                   | 122 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▍                  | 133 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▍                 | 143 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▍                | 153 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▍               | 163 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▌              | 174 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▌             | 184 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▌            | 194 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▌           | 204 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▌          | 215 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▋         | 225 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▋        | 235 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▋       | 245 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▋      | 256 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▊     | 266 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▊    | 276 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▊   | 286 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▊  | 296 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▉ | 307 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▉| 317 kB 40.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 319 kB 40.1 MB/s ',
#  '\x1b[?25hCollecting datasets<1.9.0,>=1.3.0',
#  '  Downloading datasets-1.8.0-py3-none-any.whl (237 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█▍                              | 10 kB 52.5 MB/s eta 0:00:01',
#  '\x1b[K     |██▊                             | 20 kB 59.0 MB/s eta 0:00:01',
#  '\x1b[K     |████▏                           | 30 kB 66.8 MB/s eta 0:00:01',
#  '\x1b[K     |█████▌                          | 40 kB 69.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 51 kB 69.7 MB/s eta 0:00:01',
#  '\x1b[K     |████████▎                       | 61 kB 72.4 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▋                      | 71 kB 71.7 MB/s eta 0:00:01',
#  '\x1b[K     |███████████                     | 81 kB 72.9 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▍                   | 92 kB 73.7 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▉                  | 102 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▏                | 112 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▌               | 122 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 133 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▎            | 143 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▊           | 153 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 163 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▌        | 174 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▉       | 184 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▏     | 194 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▋    | 204 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 215 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▍ | 225 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▊| 235 kB 74.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 237 kB 74.6 MB/s ',
#  '\x1b[?25hRequirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (2.23.0)',
#  'Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (0.3.4)',
#  'Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (1.1.5)',
#  'Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (1.19.5)',
#  'Collecting fsspec',
#  '  Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |██▊                             | 10 kB 44.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████▌                          | 20 kB 48.9 MB/s eta 0:00:01',
#  '\x1b[K     |████████▎                       | 30 kB 58.0 MB/s eta 0:00:01',
#  '\x1b[K     |███████████                     | 40 kB 59.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▉                  | 51 kB 61.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▋               | 61 kB 62.8 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▍            | 71 kB 63.9 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▏         | 81 kB 65.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 92 kB 66.8 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▊    | 102 kB 68.4 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▌ | 112 kB 68.4 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 118 kB 68.4 MB/s ',
#  '\x1b[?25hCollecting huggingface-hub<0.1.0',
#  '  Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |██████▌                         | 10 kB 51.0 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████                   | 20 kB 55.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▌            | 30 kB 63.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 40 kB 68.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 50 kB 9.1 MB/s ',
#  '\x1b[?25hCollecting xxhash',
#  '  Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |█▍                              | 10 kB 40.9 MB/s eta 0:00:01',
#  '\x1b[K     |██▊                             | 20 kB 48.3 MB/s eta 0:00:01',
#  '\x1b[K     |████                            | 30 kB 53.3 MB/s eta 0:00:01',
#  '\x1b[K     |█████▍                          | 40 kB 56.4 MB/s eta 0:00:01',
#  '\x1b[K     |██████▊                         | 51 kB 59.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████                        | 61 kB 63.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▍                      | 71 kB 64.8 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▊                     | 81 kB 67.3 MB/s eta 0:00:01',
#  '\x1b[K     |████████████                    | 92 kB 68.9 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▍                  | 102 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▊                 | 112 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▏               | 122 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▌              | 133 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▉             | 143 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▏           | 153 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▌          | 163 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▉         | 174 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▏       | 184 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▌      | 194 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▉     | 204 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 215 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▌  | 225 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████ | 235 kB 70.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 243 kB 70.5 MB/s ',
#  '\x1b[?25hRequirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (0.70.12.2)',
#  'Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (21.0)',
#  'Collecting tqdm<4.50.0,>=4.27',
#  '  Downloading tqdm-4.49.0-py2.py3-none-any.whl (69 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |████▊                           | 10 kB 32.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▍                      | 20 kB 37.7 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 30 kB 42.3 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▉             | 40 kB 44.8 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▌        | 51 kB 44.6 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 61 kB 46.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 69 kB 6.8 MB/s ',
#  '\x1b[?25hRequirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (4.6.4)',
#  'Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets<1.9.0,>=1.3.0->adaptnlp) (3.0.0)',
#  'Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (3.13)',
#  'Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (1.0.0)',
#  'Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (0.22.2.post1)',
#  'Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (3.2.2)',
#  'Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (1.4.1)',
#  'Collecting fastdownload<2,>=0.0.5',
#  '  Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)',
#  'Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (2.2.4)',
#  'Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (21.1.3)',
#  'Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (0.10.0+cu102)',
#  'Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.4.0->adaptnlp) (7.1.2)',
#  'Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets<1.9.0,>=1.3.0->adaptnlp) (3.7.4.3)',
#  'Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets<1.9.0,>=1.3.0->adaptnlp) (3.0.12)',
#  'Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets<1.9.0,>=1.3.0->adaptnlp) (2.4.7)',
#  'Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<1.9.0,>=1.3.0->adaptnlp) (1.24.3)',
#  'Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<1.9.0,>=1.3.0->adaptnlp) (2021.5.30)',
#  'Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<1.9.0,>=1.3.0->adaptnlp) (3.0.4)',
#  'Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<1.9.0,>=1.3.0->adaptnlp) (2.10)',
#  'Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (1.0.5)',
#  'Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (7.4.0)',
#  'Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (0.4.1)',
#  'Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (1.0.0)',
#  'Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (0.8.2)',
#  'Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (1.0.5)',
#  'Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (1.1.3)',
#  'Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (3.0.5)',
#  'Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (2.0.5)',
#  'Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.4.0->adaptnlp) (57.4.0)',
#  'Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets<1.9.0,>=1.3.0->adaptnlp) (3.5.0)',
#  'Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.0->adaptnlp) (2019.12.20)',
#  'Collecting sacremoses',
#  '  Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |▍                               | 10 kB 34.1 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 20 kB 36.7 MB/s eta 0:00:01',
#  '\x1b[K     |█                               | 30 kB 43.7 MB/s eta 0:00:01',
#  '\x1b[K     |█▌                              | 40 kB 46.3 MB/s eta 0:00:01',
#  '\x1b[K     |█▉                              | 51 kB 47.9 MB/s eta 0:00:01',
#  '\x1b[K     |██▏                             | 61 kB 51.6 MB/s eta 0:00:01',
#  '\x1b[K     |██▋                             | 71 kB 53.0 MB/s eta 0:00:01',
#  '\x1b[K     |███                             | 81 kB 55.7 MB/s eta 0:00:01',
#  '\x1b[K     |███▎                            | 92 kB 58.1 MB/s eta 0:00:01',
#  '\x1b[K     |███▋                            | 102 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████                            | 112 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████▍                           | 122 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████▊                           | 133 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████▏                          | 143 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████▌                          | 153 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████▉                          | 163 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████▎                         | 174 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████▋                         | 184 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████                         | 194 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████▎                        | 204 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████▊                        | 215 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████                        | 225 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████▍                       | 235 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████▉                       | 245 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▏                      | 256 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▌                      | 266 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▉                      | 276 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▎                     | 286 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▋                     | 296 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████                     | 307 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▍                    | 317 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▊                    | 327 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████                    | 337 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▌                   | 348 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▉                   | 358 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▏                  | 368 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▌                  | 378 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 389 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▎                 | 399 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▋                 | 409 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████                 | 419 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▍                | 430 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▊                | 440 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████                | 450 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▌               | 460 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▉               | 471 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▏              | 481 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▋              | 491 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 501 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▎             | 512 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▊             | 522 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 532 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▍            | 542 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▊            | 552 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▏           | 563 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▌           | 573 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▉           | 583 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▎          | 593 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▋          | 604 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 614 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▎         | 624 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▊         | 634 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████         | 645 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▍        | 655 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▉        | 665 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▏       | 675 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▌       | 686 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 696 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▎      | 706 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▋      | 716 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 727 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▍     | 737 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▊     | 747 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████     | 757 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▌    | 768 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▉    | 778 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 788 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▌   | 798 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 808 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▎  | 819 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▋  | 829 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 839 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▍ | 849 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▊ | 860 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▏| 870 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▌| 880 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▉| 890 kB 60.1 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 895 kB 60.1 MB/s ',
#  '\x1b[?25hCollecting huggingface-hub<0.1.0',
#  '  Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)',
#  'Collecting pyyaml',
#  '  Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)',
#  '\x1b[?25l',
#  '\x1b[K     |▌                               | 10 kB 33.5 MB/s eta 0:00:01',
#  '\x1b[K     |█                               | 20 kB 39.9 MB/s eta 0:00:01',
#  '\x1b[K     |█▌                              | 30 kB 48.2 MB/s eta 0:00:01',
#  '\x1b[K     |██                              | 40 kB 53.4 MB/s eta 0:00:01',
#  '\x1b[K     |██▋                             | 51 kB 55.1 MB/s eta 0:00:01',
#  '\x1b[K     |███                             | 61 kB 57.7 MB/s eta 0:00:01',
#  '\x1b[K     |███▋                            | 71 kB 59.4 MB/s eta 0:00:01',
#  '\x1b[K     |████▏                           | 81 kB 61.7 MB/s eta 0:00:01',
#  '\x1b[K     |████▋                           | 92 kB 63.6 MB/s eta 0:00:01',
#  '\x1b[K     |█████▏                          | 102 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████▋                          | 112 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████▏                         | 122 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████▊                         | 133 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████▏                        | 143 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████▊                        | 153 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████▎                       | 163 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████▊                       | 174 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▎                      | 184 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████▉                      | 194 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▎                     | 204 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████▉                     | 215 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▎                    | 225 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████▉                    | 235 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▍                   | 245 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████▉                   | 256 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████▍                  | 266 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████                  | 276 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████▍                 | 286 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████                 | 296 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████▍                | 307 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████                | 317 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████▌               | 327 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████               | 337 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▌              | 348 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 358 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▌             | 368 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 378 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▋            | 389 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 399 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▋           | 409 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████           | 419 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▋          | 430 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▏         | 440 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▋         | 450 kB 65.2 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▏        | 460 kB 65.2 MB/s eta 0:00:01',
# ...
#  '\x1b[K     |█████████████████▌              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▋              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▊              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████▉              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████              | 1.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▏             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▎             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▍             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▌             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▋             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▊             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████▉             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████             | 1.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▏            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▎            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▍            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▌            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▋            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▊            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████▉            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████            | 2.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▏           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▎           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▍           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▌           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▋           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▊           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████▉           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████           | 2.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▏          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▏          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▎          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▍          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▌          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▋          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▊          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████▉          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████          | 2.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▏         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▏         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▎         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▍         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▌         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▋         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▊         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████▉         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████         | 2.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▏        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▎        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▎        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▍        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▌        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▋        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▊        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████▉        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████        | 2.4 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▏       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▎       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▍       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▍       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▌       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▋       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▊       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████▉       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████       | 2.5 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▏      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▎      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▍      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▍      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▌      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▋      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▊      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████▉      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 2.6 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████      | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▏     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▎     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▍     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▌     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▌     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▋     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▊     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████▉     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████     | 2.7 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████     | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▏    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▎    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▍    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▌    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▌    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▋    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▊    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████▉    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████    | 2.8 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████    | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▏   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▎   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▍   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▌   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▋   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▋   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▊   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████▉   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 2.9 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████   | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▏  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▎  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▍  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▌  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▋  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▋  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▊  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |█████████████████████████████▉  | 3.0 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████  | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▏ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▎ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▍ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▌ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▋ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▊ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▊ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |██████████████████████████████▉ | 3.1 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████ | 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████ | 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▏| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▎| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▍| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▌| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▋| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▊| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▊| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |███████████████████████████████▉| 3.2 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 3.3 MB 53.5 MB/s eta 0:00:01',
#  '\x1b[K     |████████████████████████████████| 3.3 MB 53.5 MB/s ',
#  '\x1b[?25hCollecting wikipedia-api',
#  '  Downloading Wikipedia-API-0.5.4.tar.gz (18 kB)',
#  'Collecting deprecated>=1.2.4',
#  '  Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)',
#  'Collecting konoha<5.0.0,>=4.0.0',
#  '  Downloading konoha-4.6.5-py3-none-any.whl (20 kB)',
#  'Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from flair->adaptnlp) (0.8.9)',
#  'Collecting janome',
#  '  Downloading Janome-0.4.1-py2.py3-none-any.whl (19.7 MB)',
#  '\x1b[?25l',
#  '\x1b[K     |                                | 10 kB 4.8 MB/s eta 0:00:05',
#  '\x1b[K     |                                | 20 kB 8.5 MB/s eta 0:00:03',
#  '\x1b[K     |                                | 30 kB 11.9 MB/s eta 0:00:02',
#  '\x1b[K     |                                | 40 kB 14.6 MB/s eta 0:00:02',
#  '\x1b[K     |                                | 51 kB 17.0 MB/s eta 0:00:02',
#  '\x1b[K     |                                | 61 kB 19.6 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 71 kB 21.7 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 81 kB 23.7 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 92 kB 25.4 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 102 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 112 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 122 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▏                               | 133 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 143 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 153 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 163 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 174 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 184 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▎                               | 194 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 204 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 215 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 225 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 235 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 245 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 256 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▍                               | 266 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 276 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 286 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 296 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 307 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 317 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 327 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▌                               | 337 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 348 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 358 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 368 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 378 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 389 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▋                               | 399 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 409 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 419 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 430 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 440 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 450 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 460 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▊                               | 471 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▉                               | 481 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▉                               | 491 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▉                               | 501 kB 27.0 MB/s eta 0:00:01',
#  '\x1b[K     |▉                               | 512 kB 27.0 MB/s eta 0:00:01',
#  ...]

# %%
# !pip install nbdev
# Out:
# Collecting nbdev
#   Downloading nbdev-1.1.22-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.0 MB/s
# Collecting fastrelease
#   Downloading fastrelease-0.1.12-py3-none-any.whl (14 kB)
# Requirement already satisfied: fastcore>=1.3.21 in /usr/local/lib/python3.7/dist-packages (from nbdev) (1.3.26)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from nbdev) (5.1.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from nbdev) (5.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nbdev) (21.0)
# Requirement already satisfied: nbconvert<6 in /usr/local/lib/python3.7/dist-packages (from nbdev) (5.6.1)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.7/dist-packages (from nbdev) (1.0.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from nbdev) (21.1.3)
# Requirement already satisfied: jupyter-client<7.0 in /usr/local/lib/python3.7/dist-packages (from nbdev) (5.3.5)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from nbdev) (4.10.1)
# Collecting ghapi
#   Downloading ghapi-0.1.19-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 419 kB/s
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0->nbdev) (22.2.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0->nbdev) (5.0.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0->nbdev) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0->nbdev) (4.7.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0->nbdev) (5.1.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (0.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (2.6.1)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (2.11.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (1.4.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (4.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6->nbdev) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.4->nbconvert<6->nbdev) (2.0.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4.0->nbdev) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4.0->nbdev) (2.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client<7.0->nbdev) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert<6->nbdev) (0.5.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->nbdev) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->nbdev) (0.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->nbdev) (0.2.5)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev) (5.1.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev) (7.6.3)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev) (5.2.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from jupyter->nbdev) (5.3.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->nbdev) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->nbdev) (1.0.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->nbdev) (0.11.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->nbdev) (1.8.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->jupyter->nbdev) (0.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nbdev) (2.4.7)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.7/dist-packages (from qtconsole->jupyter->nbdev) (1.10.0)
# Installing collected packages: ghapi, fastrelease, nbdev
# Successfully installed fastrelease-0.1.12 ghapi-0.1.19 nbdev-1.1.22

# %% [markdown]
# ## Auswahl eines geeigneten Modells

# %%
from adaptnlp import HFModelHub, HF_TASKS

# %%
hub = HFModelHub()

# %%
models = hub.search_model_by_task(HF_TASKS.TEXT_CLASSIFICATION)

# %%
models[:10]
# Out:
# [Model Name: distilbert-base-uncased-finetuned-sst-2-english, Tasks: [text-classification],
#  Model Name: roberta-base-openai-detector, Tasks: [text-classification],
#  Model Name: roberta-large-mnli, Tasks: [text-classification],
#  Model Name: roberta-large-openai-detector, Tasks: [text-classification]]

# %%
models = hub.search_model_by_task(
    task=HF_TASKS.TEXT_CLASSIFICATION
)

# %%
models[:5]
# Out:
# [Model Name: distilbert-base-uncased-finetuned-sst-2-english, Tasks: [text-classification],
#  Model Name: roberta-base-openai-detector, Tasks: [text-classification],
#  Model Name: roberta-large-mnli, Tasks: [text-classification],
#  Model Name: roberta-large-openai-detector, Tasks: [text-classification]]

# %%
model = models[0]
model
# Out:
# Model Name: distilbert-base-uncased-finetuned-sst-2-english, Tasks: [text-classification]

# %% [markdown]
# ## Aufbau Datenset

# %%
from fastai.data.external import URLs, untar_data

# %%
data_path = untar_data(URLs.IMDB_SAMPLE)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='573440' class='' max='571827' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.28% [573440/571827 00:00<00:00]
#     </div>

# %%
data_path.ls()
# Out:
# (#1) [Path('/root/.fastai/data/imdb_sample/texts.csv')]

# %%
from adaptnlp import SequenceClassificationDatasets

# %%
from nbverbose.showdoc import *
from adaptnlp import SequenceClassificationDatasets
show_doc(SequenceClassificationDatasets.from_csvs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-178eb227aded> in <module>()
# ----> 1 from nbverbose.showdoc import *
#       2 from adaptnlp import SequenceClassificationDatasets
#       3 show_doc(SequenceClassificationDatasets.from_csvs)
#
# ModuleNotFoundError: No module named 'nbverbose'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Wir schreiben eine tokenizer Funktion, die folgende Parameter akzeptiert:
#
# * `item`
# * `tokenizer`
# * `tokenizer_kwargs`

# %%
def tok_func(item, tokenizer, tokenize_kwargs):
  return tokenizer(item['sentence1'], item['sentence2'], **tokenize_kwargs)

# %%
from nbdev.showdoc import *
show_doc(TaskDatasets)
# Out:
# <h2 id="TaskDatasets" class="doc_header"><code>class</code> <code>TaskDatasets</code><a href="https://github.com/novetta/adaptnlp/tree/master/adaptnlp/training/core.py#L168" class="source_link" style="float:right">[source]</a></h2>
#
# > <code>TaskDatasets</code>(**`train_dset`**, **`valid_dset`**, **`tokenizer_name`**:`str`=*`None`*, **`tokenize`**:`bool`=*`True`*, **`tokenize_func`**:`callable`=*`None`*, **`tokenize_kwargs`**:`dict`=*`{}`*, **`auto_kwargs`**:`dict`=*`{}`*, **`remove_cols`**:`Union`\[`str`, `List`\[`str`\]\]=*`None`*, **`label_keys`**:`list`=*`['labels']`*)
#
# A set of datasets for a particular task, with a simple API.
#
# Note: This is the base API, `items` should be a set of regular text and model-ready labels,
#       including label or one-hot encoding being applied.

# %%
remove_cols=['sentence1', 'sentence2', 'idx']
tokenize_kwargs = {'max_length':64, 'padding':True}

# %%
dsets = TaskDatasets(
    raw_datasets['train'], raw_datasets['validation'],
    tokenizer_name = model_name,
    tokenize_kwargs = tokenize_kwargs,
    tokenize_func = tok_func,
    remove_cols = remove_cols
)
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/glue/mrpc/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-10e15044f80459ba.arrow
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
from transformers import DataCollatorWithPadding

# %%
dls = dsets.dataloaders(
    batch_size=8, 
    collate_fn=DataCollatorWithPadding(tokenizer=dsets.tokenizer)
)

# %%
dls.show_batch(n=4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input</th>
#       <th>Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>in his female disguise, the real estate heir used the name dorothy ciner, a childhood friend. in his female disguise, he used the name dorothy ciner, a childhood friend, and rented an apartment in galveston.</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>of the 23. 5 million high - speed lines, 16. 3 million provided advanced services, which the fcc defines as speeds exceeding 200 kbps in both directions. a total of 16. 3 million lines provided advanced services, those services at speeds exceeding 200 kbps in both directions.</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>sirius recently began carrying national public radio, a deal pooh - poohed by xm because it doesn't include popular shows like " all things considered " and " morning edition. " sirius carries national public radio, although it doesn't include popular shows such as " all things considered " and " morning edition. "</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>in late morning trading, the dow was up 13. 88, or 0. 2 percent, at 9, 002. 93, having shed 2. 3 percent last week. in early trading, the dow jones industrial average was down 39. 94, or 0. 4 percent, at 8, 945. 50, having slipped 3. 61 points monday.</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Finetuning
# Für das Finetuning verwenden wir den `SequenceClassificationTuner`.

# %%
from adaptnlp import SequenceClassificationTuner, Strategy

# %%
show_doc(SequenceClassificationTuner)
# Out:
# <h2 id="SequenceClassificationTuner" class="doc_header"><code>class</code> <code>SequenceClassificationTuner</code><a href="https://github.com/novetta/adaptnlp/tree/master/adaptnlp/training/sequence_classification.py#L222" class="source_link" style="float:right">[source]</a></h2>
#
# > <code>SequenceClassificationTuner</code>(**`dls`**:`DataLoaders`, **`model_name`**:`str`, **`tokenizer`**=*`None`*, **`loss_func`**=*`CrossEntropyLoss()`*, **`metrics`**=*`[<function accuracy at 0x7fdfcacfecb0>, <fastai.metrics.AccumMetric object at 0x7fdfcac78090>]`*, **`opt_func`**=*`Adam`*, **`additional_cbs`**=*`None`*, **`expose_fastai_api`**=*`False`*, **`num_classes`**:`int`=*`None`*, **\*\*`kwargs`**) :: `AdaptiveTuner`
#
# An `AdaptiveTuner` with good defaults for Sequence Classification tasks
#
# **Valid kwargs and defaults:**
#   - `lr`:float = 0.001
#   - `splitter`:function = `trainable_params`
#   - `cbs`:list = None
#   - `path`:Path = None
#   - `model_dir`:Path = 'models'
#   - `wd`:float = None
#   - `wd_bn_bias`:bool = False
#   - `train_bn`:bool = True
#   - `moms`: tuple(float) = (0.95, 0.85, 0.95)

# %%
tuner = SequenceClassificationTuner(dls, model.name, num_classes=2)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e352b6fa9901> in <module>()
# ----> 1 tuner = SequenceClassificationTuner(dls, model.name, num_classes=2)
#
# /usr/local/lib/python3.7/dist-packages/adaptnlp/training/sequence_classification.py in __init__(self, dls, model_name, tokenizer, loss_func, metrics, opt_func, additional_cbs, expose_fastai_api, num_classes, **kwargs)
#     267             opt_func = opt_func,
#     268             cbs=additional_cbs,
# --> 269             **kwargs
#     270         )
#     271
#
# /usr/local/lib/python3.7/dist-packages/adaptnlp/training/core.py in __init__(self, expose_fastai, tokenizer, label_keys, **kwargs)
#     382     ):
#     383         "Fine tune `self.model` for `epochs` with an `lr` and `strategy`"
# --> 384         func = getattr(self, strategy, getattr(self._tuner, strategy, None))
#     385         for attr in 'epochs,lr,cbs'.split():
#     386             if attr in kwargs.keys(): kwargs.pop(attr)
#
# TypeError: __init__() got an unexpected keyword argument 'label_keys'

# %%
show_doc(SequenceClassificationTuner.tune)

# %%
tuner.tune(3, 5e-5, strategy=Strategy.OneCycle)

# %%
tuner.save('fine_tuned_model')
